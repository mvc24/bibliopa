# %%
import json
import sys
from rich import print as rprint
from pathlib import Path

nb_dir = Path.cwd()

project_root = nb_dir.parent.parent

sys.path.insert(0, str(project_root))


from scripts.text_matching import normalise_text

# %%
folder_parsedfolder_prepped = Path(project_root / "data/prepped")
people_file = Path(project_root / "data/people/people_extracted.json")
variants_file = Path(project_root / "data/from db/people_variants.json")

matched_file = Path(project_root / "data/people/people_matched.json")
unmatched_file = Path(project_root / "data/people/people_unmatched.json")

# %%
with open(people_file, "r") as f:
    people_dict = json.load(f)

with open(variants_file, "r") as f:
    variants = json.load(f)

variants_dict = {normalise_text(variant["variant_normalised"]): variant for variant in variants}
# rprint(dict(list(variants_dict.items())[:3]))
# rprint(dict(list(people_dict.items())[:3]))
# rprint(dict(list(people_dict.items())[:3]))

matched = {}
unmatched = {}
matching_log = {}

matched_count = 0
unmatched_count = 0

for name, values in people_dict.items():
    if name in variants_dict:
        variant = variants_dict[name]
        matched[name] = {
            "variant_id": variant["variant_id"],
            "person_id": variant["person_id"],
            "unified_id": variant["unified_id"],
            "occurrences": values
        }
        matched_count += 1
    else:
        unmatched[name] = values
        unmatched_count += 1

# rprint(dict(list(matched.items())[:10]))
# rprint(dict(list(unmatched.items())[:10]))

unique_people = len(people_dict)
percent_matched = (matched_count / unique_people) * 100
percent_unmatched = (unmatched_count / unique_people) * 100


matching_log = {
    "unique_people": unique_people,
    "people_occurrences": sum(len(v) for v in people_dict.values()),
    "matched": matched_count,
    "pct_matched": percent_matched,
    "unmatched": unmatched_count,
    "pct_unmatched": percent_unmatched
    }

rprint(matching_log)

with open(matched_file, "w") as f:
    json.dump(matched, f, ensure_ascii=False, indent=2)
with open(unmatched_file, "w") as f:
    json.dump(unmatched, f, ensure_ascii=False, indent=2)
# Out:
# {
#     'löbl, emil': {
#         'variant_id': 5359,
#         'person_id': 4181,
#         'unified_id': 'lobl_emil',
#         'occurrences': [
#             {
#                 'display_name': 'LÖBL, Emil',
#                 'composite_id': 'wien_201_9_10',
#                 'sort_order': 1,
#                 'is_author': True,
#                 'is_editor': False,
#                 'is_contributor': False,
#                 'is_translator': False
#             },
#             {
#                 'display_name': 'LÖBL, Emil',
#                 'composite_id': 'erstausgaben_1204_49_78',
#                 'sort_order': 1,
#                 'is_author': True,
#                 'is_editor': False,
#                 'is_contributor': False,
#                 'is_translator': False
#             }
#         ]
#     },
#     'mailler, hermann': {
#         'variant_id': 5536,
#         'person_id': 4342,
#         'unified_id': 'mailler_hermann',
#         'occurrences': [
#             {
#                 'display_name': 'MAILLER, Hermann',
#                 'composite_id': 'wien_203_9_10',
#                 'sort_order': 1,
#                 'is_author': True,
#                 'is_editor': False,
#                 'is_contributor': False,
#                 'is_translator': False
#             },
#             {
#                 'display_name': 'Mailler, Hermann',
#                 'composite_id': 'wien_162_7_10',
#                 'sort_order': 1,
#                 'is_author': False,
#                 'is_editor': False,
#                 'is_contributor': True,
#                 'is_translator': False
#             }
#         ]
#     },
#     'minder, robert a.': {
#         'variant_id': 5929,
#         'person_id': 4671,
#         'unified_id': 'minder_robert_a',
#         'occurrences': [
#             {
#                 'display_name': 'MINDER, Robert A.',
#                 'composite_id': 'wien_205_9_10',
#                 'sort_order': 1,
#                 'is_author': True,
#                 'is_editor': False,
#                 'is_contributor': False,
#                 'is_translator': False
#             }
#         ]
#     },
#     'pemmer, hans': {
#         'variant_id': 6513,
#         'person_id': 5178,
#         'unified_id': 'pemmer_hans',
#         'occurrences': [
#             {
#                 'display_name': 'PEMMER, Hans',
#                 'composite_id': 'wien_206_9_10',
#                 'sort_order': 1,
#                 'is_author': True,
#                 'is_editor': False,
#                 'is_contributor': False,
#                 'is_translator': False
#             },
#             {
#                 'display_name': 'PEMMER, Hans',
#                 'composite_id': 'wien_86_4_10',
#                 'sort_order': 1,
#                 'is_author': True,
#                 'is_editor': False,
#                 'is_contributor': False,
#                 'is_translator': False
#             }
#         ]
#     },
#     'lackner, nini': {
#         'variant_id': 5002,
#         'person_id': 3880,
#         'unified_id': 'lackner_nini',
#         'occurrences': [
#             {
#                 'display_name': 'LACKNER, Nini',
#                 'composite_id': 'wien_206_9_10',
#                 'sort_order': 2,
#                 'is_author': True,
#                 'is_editor': False,
#                 'is_contributor': False,
#                 'is_translator': False
#             }
#         ]
#     },
#     'düriegl, günter': {
#         'variant_id': 2201,
#         'person_id': 1505,
#         'unified_id': 'duriegl_gunter',
#         'occurrences': [
#             {
#                 'display_name': 'Düriegl, Günter',
#                 'composite_id': 'wien_206_9_10',
#                 'sort_order': 1,
#                 'is_author': False,
#                 'is_editor': False,
#                 'is_contributor': True,
#                 'is_translator': False
#             },
#             {
#                 'display_name': 'Düriegl, Günter',
#                 'composite_id': 'wien_139_6_10',
#                 'sort_order': 2,
#                 'is_author': False,
#                 'is_editor': False,
#                 'is_contributor': True,
#                 'is_translator': False
#             }
#         ]
#     },
#     'sackmauer, ludwig': {
#         'variant_id': 7345,
#         'person_id': 5887,
#         'unified_id': 'sackmauer_ludwig',
#         'occurrences': [
#             {
#                 'display_name': 'Sackmauer, Ludwig',
#                 'composite_id': 'wien_206_9_10',
#                 'sort_order': 2,
#                 'is_author': False,
#                 'is_editor': False,
#                 'is_contributor': True,
#                 'is_translator': False
#             }
#         ]
#     },
#     'rabinovici, doron': {
#         'variant_id': 6853,
#         'person_id': 5467,
#         'unified_id': 'rabinovici_doron',
#         'occurrences': [
#             {
#                 'display_name': 'RABINOVICI, Doron',
#                 'composite_id': 'wien_207_9_10',
#                 'sort_order': 1,
#                 'is_author': True,
#                 'is_editor': False,
#                 'is_contributor': False,
#                 'is_translator': False
#             },
#             {
#                 'display_name': 'RABINOVICI, Doron',
#                 'composite_id': 'judentum_128_6_9',
#                 'sort_order': 1,
#                 'is_author': True,
#                 'is_editor': False,
#                 'is_contributor': False,
#                 'is_translator': False
#             },
#             {
#                 'display_name': 'RABINOVICI, Doron',
#                 'composite_id': 'erstausgaben_1531_62_78',
#                 'sort_order': 1,
#                 'is_author': True,
#                 'is_editor': False,
#                 'is_contributor': False,
#                 'is_translator': False
#             },
#             {
#                 'display_name': 'RABINOVICI, Doron',
#                 'composite_id': 'erstausgaben_1532_62_78',
#                 'sort_order': 1,
#                 'is_author': True,
#                 'is_editor': False,
#                 'is_contributor': False,
#                 'is_translator': False
#             },
#             {
#                 'display_name': 'RABINOVICI, Doron',
#                 'composite_id': 'erstausgaben_1533_62_78',
#                 'sort_order': 1,
#                 'is_author': True,
#                 'is_editor': False,
#                 'is_contributor': False,
#                 'is_translator': False
#             },
#             {
#                 'display_name': 'RABINOVICI, Doron',
#                 'composite_id': 'erstausgaben_1534_62_78',
#                 'sort_order': 1,
#                 'is_author': True,
#                 'is_editor': False,
#                 'is_contributor': False,
#                 'is_translator': False
#             }
#         ]
#     },
#     'roessler, arthur': {
#         'variant_id': 7153,
#         'person_id': 5734,
#         'unified_id': 'roessler_arthur',
#         'occurrences': [
#             {
#                 'display_name': 'ROESSLER, Arthur',
#                 'composite_id': 'wien_209_9_10',
#                 'sort_order': 1,
#                 'is_author': True,
#                 'is_editor': False,
#                 'is_contributor': False,
#                 'is_translator': False
#             },
#             {
#                 'display_name': 'ROESSLER, Arthur',
#                 'composite_id': 'kunstbuecher_867_35_38',
#                 'sort_order': 1,
#                 'is_author': True,
#                 'is_editor': False,
#                 'is_contributor': False,
#                 'is_translator': False
#             },
#             {
#                 'display_name': 'ROESSLER, Arthur',
#                 'composite_id': 'kunstbuecher_868_35_38',
#                 'sort_order': 1,
#                 'is_author': True,
#                 'is_editor': False,
#                 'is_contributor': False,
#                 'is_translator': False
#             },
#             {
#                 'display_name': 'ROESSLER, Arthur',
#                 'composite_id': 'kunstbuecher_869_35_38',
#                 'sort_order': 1,
#                 'is_author': True,
#                 'is_editor': False,
#                 'is_contributor': False,
#                 'is_translator': False
#             },
#             {
#                 'display_name': 'ROESSLER, Arthur',
#                 'composite_id': 'kunstbuecher_447_18_38',
#                 'sort_order': 1,
#                 'is_author': True,
#                 'is_editor': False,
#                 'is_contributor': False,
#                 'is_translator': False
#             }
#         ]
#     },
#     'schlögl, friedrich': {
#         'variant_id': 7595,
#         'person_id': 6101,
#         'unified_id': 'schlogl_friedrich',
#         'occurrences': [
#             {
#                 'display_name': 'SCHLÖGL, Friedrich',
#                 'composite_id': 'wien_212_9_10',
#                 'sort_order': 1,
#                 'is_author': True,
#                 'is_editor': False,
#                 'is_contributor': False,
#                 'is_translator': False
#             },
#             {
#                 'display_name': 'SCHLÖGL, Friedrich',
#                 'composite_id': 'wien_213_9_10',
#                 'sort_order': 1,
#                 'is_author': True,
#                 'is_editor': False,
#                 'is_contributor': False,
#                 'is_translator': False
#             },
#             {
#                 'display_name': 'SCHLÖGL, Friedrich',
#                 'composite_id': 'wien_103_5_10',
#                 'sort_order': 1,
#                 'is_author': True,
#                 'is_editor': False,
#                 'is_contributor': False,
#                 'is_translator': False
#             },
#             {
#                 'display_name': 'SCHLÖGL, Friedrich',
#                 'composite_id': 'wien_104_5_10',
#                 'sort_order': 1,
#                 'is_author': True,
#                 'is_editor': False,
#                 'is_contributor': False,
#                 'is_translator': False
#             }
#         ]
#     }
# }
# {
#     'reiffenstein, bruno': [
#         {
#             'display_name': 'Reiffenstein, Bruno',
#             'composite_id': 'wien_209_9_10',
#             'sort_order': 1,
#             'is_author': False,
#             'is_editor': False,
#             'is_contributor': True,
#             'is_translator': False
#         }
#     ],
#     'rommel, otto': [
#         {
#             'display_name': 'ROMMEL, Otto',
#             'composite_id': 'wien_210_9_10',
#             'sort_order': 1,
#             'is_author': True,
#             'is_editor': False,
#             'is_contributor': False,
#             'is_translator': False
#         },
#         {
#             'display_name': 'Rommel, Otto',
#             'composite_id': 'briefe_45_2_15',
#             'sort_order': 2,
#             'is_author': False,
#             'is_editor': True,
#             'is_contributor': False,
#             'is_translator': False
#         }
#     ],
#     'schreck, joachim': [
#         {
#             'display_name': 'Schreck, Joachim',
#             'composite_id': 'wien_216_9_10',
#             'sort_order': 1,
#             'is_author': False,
#             'is_editor': True,
#             'is_contributor': False,
#             'is_translator': False
#         },
#         {
#             'display_name': 'Schreck, Joachim',
#             'composite_id': 'literatur_254_11_12',
#             'sort_order': 1,
#             'is_author': False,
#             'is_editor': True,
#             'is_contributor': False,
#             'is_translator': False
#         }
#     ],
#     'karl albrecht-weinberger': [
#         {
#             'display_name': 'Karl Albrecht-Weinberger',
#             'composite_id': 'wien_219_9_10',
#             'sort_order': 1,
#             'is_author': False,
#             'is_editor': False,
#             'is_contributor': True,
#             'is_translator': False
#         }
#     ],
#     'stigler-fuchs, margarete von': [
#         {
#             'display_name': 'STIGLER-FUCHS, Margarete von',
#             'composite_id': 'wien_220_9_10',
#             'sort_order': 1,
#             'is_author': True,
#             'is_editor': False,
#             'is_contributor': False,
#             'is_translator': False
#         },
#         {
#             'display_name': 'STIGLER-FUCHS, Margarete von',
#             'composite_id': 'wien_221_9_10',
#             'sort_order': 1,
#             'is_author': True,
#             'is_editor': False,
#             'is_contributor': False,
#             'is_translator': False
#         }
#     ],
#     'cerny, elfriede': [
#         {
#             'display_name': 'Cerny, Elfriede',
#             'composite_id': 'wien_220_9_10',
#             'sort_order': 1,
#             'is_author': False,
#             'is_editor': False,
#             'is_contributor': True,
#             'is_translator': False
#         }
#     ],
#     'wellesz, emmy': [
#         {
#             'display_name': 'Wellesz, Emmy',
#             'composite_id': 'wien_224_9_10',
#             'sort_order': 1,
#             'is_author': False,
#             'is_editor': False,
#             'is_contributor': True,
#             'is_translator': False
#         }
#     ],
#     'raykowski, harald': [
#         {
#             'display_name': 'Raykowski, Harald',
#             'composite_id': 'de-lit-texte_149_6_20',
#             'sort_order': 1,
#             'is_author': False,
#             'is_editor': False,
#             'is_contributor': True,
#             'is_translator': False
#         }
#     ],
#     'stadt mödling': [
#         {
#             'display_name': 'Stadt Mödling',
#             'composite_id': 'erstausgaben_1458_59_78',
#             'sort_order': 1,
#             'is_author': False,
#             'is_editor': True,
#             'is_contributor': False,
#             'is_translator': False
#         }
#     ],
#     'holzmeister, clemens': [
#         {
#             'display_name': 'Holzmeister, Clemens',
#             'composite_id': 'erstausgaben_1465_59_78',
#             'sort_order': 1,
#             'is_author': False,
#             'is_editor': False,
#             'is_contributor': True,
#             'is_translator': False
#         }
#     ]
# }
