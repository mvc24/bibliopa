# %%
import json
import sys
from rich import print as rprint
from pprint import pp
from pathlib import Path
import re
from itertools import batched

nb_dir = Path.cwd()

project_root = nb_dir.parent.parent

sys.path.insert(0, str(project_root))

# %%
books_folder = Path(project_root / "data_reload/books/prepped")
batched_folder = Path(project_root / "data_reload/books/loading_batches")

total_books = 0
all_books = {}

for file in books_folder.iterdir():
    with open(file, "r") as f:
       books = json.load(f)
    book_count = len(books)
    total_books += book_count
    all_books.update(books)

# rprint(f"total after loop: {total_books}")
# rprint(dict(list(all_books.items())[:2]))

# %%
i = 0

for batch in batched(all_books.items(), 200):
    book_batch = dict(batch)
    i += 1
    batch_id = str(i).zfill(2)
    filename = "books4loading_" + batch_id + ".json"
    file_path = batched_folder / filename
    # rprint(file_path)
    with open(file_path, "w") as f:
        json.dump(book_batch, f, ensure_ascii=False, indent=2)
    rprint(f"wrote & saved {filename}")
# Out:
# wrote & saved books4loading_01.json
# wrote & saved books4loading_02.json
# wrote & saved books4loading_03.json
# wrote & saved books4loading_04.json
# wrote & saved books4loading_05.json
# wrote & saved books4loading_06.json
# wrote & saved books4loading_07.json
# wrote & saved books4loading_08.json
# wrote & saved books4loading_09.json
# wrote & saved books4loading_10.json
# wrote & saved books4loading_11.json
# wrote & saved books4loading_12.json
# wrote & saved books4loading_13.json
# wrote & saved books4loading_14.json
# wrote & saved books4loading_15.json
# wrote & saved books4loading_16.json
# wrote & saved books4loading_17.json
# wrote & saved books4loading_18.json
# wrote & saved books4loading_19.json
# wrote & saved books4loading_20.json
# wrote & saved books4loading_21.json
# wrote & saved books4loading_22.json
# wrote & saved books4loading_23.json
# wrote & saved books4loading_24.json
# wrote & saved books4loading_25.json
# wrote & saved books4loading_26.json
# wrote & saved books4loading_27.json
# wrote & saved books4loading_28.json
# wrote & saved books4loading_29.json
# wrote & saved books4loading_30.json
# wrote & saved books4loading_31.json
# wrote & saved books4loading_32.json
# wrote & saved books4loading_33.json
# wrote & saved books4loading_34.json
# wrote & saved books4loading_35.json
# wrote & saved books4loading_36.json
# wrote & saved books4loading_37.json
# wrote & saved books4loading_38.json
# wrote & saved books4loading_39.json
# wrote & saved books4loading_40.json
# wrote & saved books4loading_41.json
# wrote & saved books4loading_42.json
# wrote & saved books4loading_43.json
# wrote & saved books4loading_44.json
# wrote & saved books4loading_45.json
# wrote & saved books4loading_46.json
# wrote & saved books4loading_47.json
# wrote & saved books4loading_48.json
# wrote & saved books4loading_49.json
# wrote & saved books4loading_50.json
# wrote & saved books4loading_51.json
# wrote & saved books4loading_52.json
# wrote & saved books4loading_53.json
# wrote & saved books4loading_54.json
# wrote & saved books4loading_55.json

# %%
import pprint

books_folder = Path(project_root / "data_reload/books/loading_batches")

# books_folder = Path("data_reload/books/loading_batches")

finished_batches = set()
finished = []
errors = []
loading_log = {
    "finished": [],
    "errors": []
}
files = sorted(books_folder.glob("*.json"))
total_files = len(files)

for file_idx, file in enumerate(files, start=1):
    filename = file.name
    rprint(f"[{file_idx}/{total_files}] Starting {filename}...")
    if filename in finished_batches:
        continue

    with open(file, "r") as f:
        books = json.load(f)

        for composite_id, book in books.items():
            book_data = book[0]["books_data"]

            rprint(book_data)
            break

            #     with connection.begin_nested():
            #         connection.execute(books_insert, {
            #             'composite_id': book['composite_id'],
            #         })

            # except IntegrityError as e:
            #     errors.append({
            #         'book': book,
            #         'error': str(e.orig).strip(),
            #     })
        # rprint(f"[{file_idx}/{total_files}] Finished {filename} ({len(books)} entries)")
# Out:
# [1/55] Starting books4loading_01.json...
# {
#     'composite_id': 'symbolkunde_0_1_2',
#     'is_active': 1,
#     'title': 'Lexikon der Symbole',
#     'subtitle': None,
#     'publisher': 'Komet Lizenzausgabe',
#     'place_of_publication': 'Frechen',
#     'publication_year': None,
#     'edition': None,
#     'pages': 352,
#     'format_original': 'OPbd.m.OU',
#     'format_expanded': 'Originalpappband mit Originalumschlag',
#     'condition': 'Neu',
#     'copies': 1,
#     'illustrations': 'Mit über 900 Abbildungen',
#     'packaging': None,
#     'topic_id': 5,
#     'is_translation': False,
#     'original_language': None,
#     'is_multivolume': False,
#     'series_title': None,
#     'total_volumes': None
# }
# [2/55] Starting books4loading_02.json...
# {
#     'composite_id': 'fremdsprachige_917_37_38',
#     'is_active': 1,
#     'title': 'Quintett in Buenos Aires',
#     'subtitle': 'Ein Pepe Carvalho Roman',
#     'publisher': 'Piper',
#     'place_of_publication': 'München',
#     'publication_year': 1997,
#     'edition': 'Dt. EA',
#     'pages': 536,
#     'format_original': 'OPbd.m.OU.und Lesebändchen',
#     'format_expanded': 'Originalpappband mit Originalumschlag und Lesebändchen',
#     'condition': 'Verlagsfrisch',
#     'copies': 1,
#     'illustrations': None,
#     'packaging': None,
#     'topic_id': 4,
#     'is_translation': True,
#     'original_language': 'Spanisch',
#     'is_multivolume': False,
#     'series_title': None,
#     'total_volumes': None
# }
# [3/55] Starting books4loading_03.json...
# {
#     'composite_id': 'fremdsprachige_846_34_38',
#     'is_active': 1,
#     'title': 'Antigone',
#     'subtitle': None,
#     'publisher': 'Residenzverlag',
#     'place_of_publication': 'Salzburg',
#     'publication_year': 1965,
#     'edition': None,
#     'pages': 40,
#     'format_original': 'Großformat. OLn.m.OU in Schuber',
#     'format_expanded': 'Großformat, Originalleinen mit Originalumschlag in Schuber',
#     'condition': 'Neuwertig',
#     'copies': 1,
#     'illustrations': 'unpag. Bildtafeln, Fotografie Josef Dapra',
#     'packaging': 'Schuber',
#     'topic_id': 4,
#     'is_translation': True,
#     'original_language': 'Altgriechisch',
#     'is_multivolume': False,
#     'series_title': 'Antikenzyklus des Burgtheaters',
#     'total_volumes': None
# }
# [4/55] Starting books4loading_04.json...
# {
#     'composite_id': 'griechenland_43_2_10',
#     'is_active': 1,
#     'title': 'Die Sklaverei in der Antike',
#     'subtitle': 'Geschichte und Probleme',
#     'publisher': 'Beck',
#     'place_of_publication': 'München',
#     'publication_year': 1981,
#     'edition': None,
#     'pages': 242,
#     'format_original': 'OLn.m.OU',
#     'format_expanded': 'Originalleinen mit Originalumschlag',
#     'condition': 'Neuwertig',
#     'copies': 1,
#     'illustrations': None,
#     'packaging': None,
#     'topic_id': 44,
#     'is_translation': False,
#     'original_language': None,
#     'is_multivolume': False,
#     'series_title': None,
#     'total_volumes': None
# }
# [5/55] Starting books4loading_05.json...
# {
#     'composite_id': 'christentum_41_2_6',
#     'is_active': 2,
#     'title': 'Das Labyrinth der Welt und andere Schriften',
#     'subtitle': None,
#     'publisher': 'Reclam',
#     'place_of_publication': 'Leipzig',
#     'publication_year': 1984,
#     'edition': None,
#     'pages': 299,
#     'format_original': 'TB',
#     'format_expanded': 'Taschenbuch',
#     'condition': None,
#     'copies': None,
#     'illustrations': 'Mit 6 Abbildungen und 1 Faksimile einer Kantional-Vorrede',
#     'packaging': None,
#     'topic_id': 7,
#     'is_translation': True,
#     'original_language': 'Tschechisch und Latein',
#     'is_multivolume': False,
#     'series_title': None,
#     'total_volumes': None
# }
# [6/55] Starting books4loading_06.json...
# {
#     'composite_id': 'antike_157_7_9',
#     'is_active': 1,
#     'title': 'Sämtliche Komödien',
#     'subtitle': None,
#     'publisher': 'Artemis',
#     'place_of_publication': 'Zürich',
#     'publication_year': 1962,
#     'edition': 'Buchgemeinschaftsausgabe',
#     'pages': None,
#     'format_original': 'Orig. Kunstleder u. OU',
#     'format_expanded': 'Original Kunstleder mit Originalumschlag',
#     'condition': 'Neuwertige Bände',
#     'copies': None,
#     'illustrations': None,
#     'packaging': None,
#     'topic_id': 18,
#     'is_translation': True,
#     'original_language': 'Griechisch',
#     'is_multivolume': True,
#     'series_title': None,
#     'total_volumes': 2
# }
# [7/55] Starting books4loading_07.json...
# {
#     'composite_id': 'erstausgaben_1215_49_78',
#     'is_active': 1,
#     'title': 'Die Rückkehr vom Hades',
#     'subtitle': 'Novellen',
#     'publisher': 'Insel',
#     'place_of_publication': 'Leipzig',
#     'publication_year': 1911,
#     'edition': None,
#     'pages': None,
#     'format_original': 'HLn.d.Zt.',
#     'format_expanded': 'Halbleinen der Zeit',
#     'condition': 'mit Rückenschild. Gut erhalten.',
#     'copies': None,
#     'illustrations': None,
#     'packaging': None,
#     'topic_id': 27,
#     'is_translation': False,
#     'original_language': None,
#     'is_multivolume': False,
#     'series_title': None,
#     'total_volumes': None
# }
# [8/55] Starting books4loading_08.json...
# {
#     'composite_id': 'erstausgaben_170_7_78',
#     'is_active': 0,
#     'title': 'Die Radiofamilie',
#     'subtitle': None,
#     'publisher': 'Suhrkamp',
#     'place_of_publication': 'Frankfurt',
#     'publication_year': 2011,
#     'edition': 'Erste Auflage',
#     'pages': 410,
#     'format_original': 'Opbd.m.OU',
#     'format_expanded': 'Originalpappband mit Originalumschlag',
#     'condition': 'Verlagsfrisch',
#     'copies': 1,
#     'illustrations': None,
#     'packaging': None,
#     'topic_id': 27,
#     'is_translation': False,
#     'original_language': None,
#     'is_multivolume': False,
#     'series_title': None,
#     'total_volumes': None
# }
# [9/55] Starting books4loading_09.json...
# {
#     'composite_id': 'erstausgaben_1668_67_78',
#     'is_active': 1,
#     'title': 'Tropen Über das Erhabene',
#     'subtitle': None,
#     'publisher': 'Hanser',
#     'place_of_publication': 'München',
#     'publication_year': 1998,
#     'edition': None,
#     'pages': 212,
#     'format_original': 'OPbd.m.OU',
#     'format_expanded': 'Originalpappband mit Originalumschlag',
#     'condition': 'Verlagsfrisch',
#     'copies': 1,
#     'illustrations': None,
#     'packaging': None,
#     'topic_id': 27,
#     'is_translation': False,
#     'original_language': None,
#     'is_multivolume': False,
#     'series_title': None,
#     'total_volumes': None
# }
# [10/55] Starting books4loading_10.json...
# {
#     'composite_id': 'erstausgaben_401_17_78',
#     'is_active': 1,
#     'title': 'Theaterschriften und Reden',
#     'subtitle': None,
#     'publisher': 'Arche',
#     'place_of_publication': 'Zürich',
#     'publication_year': 1966,
#     'edition': None,
#     'pages': 357,
#     'format_original': 'OLn.',
#     'format_expanded': 'Originalleinen',
#     'condition': 'Sehr gut erhalten',
#     'copies': 2,
#     'illustrations': None,
#     'packaging': None,
#     'topic_id': 27,
#     'is_translation': False,
#     'original_language': None,
#     'is_multivolume': False,
#     'series_title': None,
#     'total_volumes': None
# }
# [11/55] Starting books4loading_11.json...
# {
#     'composite_id': 'erstausgaben_1279_52_78',
#     'is_active': 2,
#     'title': 'Das andere Gesicht',
#     'subtitle': 'Roman',
#     'publisher': 'Residenz',
#     'place_of_publication': 'Salzburg',
#     'publication_year': 1982,
#     'edition': None,
#     'pages': 313,
#     'format_original': 'OLOn.m.OU',
#     'format_expanded': 'Originalleinen mit Originalumschlag',
#     'condition': 'Verlagsfrisch',
#     'copies': None,
#     'illustrations': None,
#     'packaging': None,
#     'topic_id': 27,
#     'is_translation': False,
#     'original_language': None,
#     'is_multivolume': False,
#     'series_title': None,
#     'total_volumes': None
# }
# [12/55] Starting books4loading_12.json...
# {
#     'composite_id': 'erstausgaben_1411_57_78',
#     'is_active': 1,
#     'title': 'Hinkemann',
#     'subtitle': 'Eine Tragödie',
#     'publisher': 'Kiepenheuer',
#     'place_of_publication': 'Potsdam',
#     'publication_year': 1924,
#     'edition': None,
#     'pages': 60,
#     'format_original': 'OHln.',
#     'format_expanded': 'Originalhalbleinen',
#     'condition': 'Bibliotheksex.',
#     'copies': 1,
#     'illustrations': None,
#     'packaging': None,
#     'topic_id': 27,
#     'is_translation': False,
#     'original_language': None,
#     'is_multivolume': False,
#     'series_title': None,
#     'total_volumes': None
# }
# [13/55] Starting books4loading_13.json...
# {
#     'composite_id': 'erstausgaben_1741_70_78',
#     'is_active': 1,
#     'title': 'Herkunft',
#     'subtitle': None,
#     'publisher': 'Hanser',
#     'place_of_publication': 'München',
#     'publication_year': 2014,
#     'edition': None,
#     'pages': 95,
#     'format_original': 'OLn.',
#     'format_expanded': 'Originalleinen',
#     'condition': None,
#     'copies': None,
#     'illustrations': None,
#     'packaging': None,
#     'topic_id': 27,
#     'is_translation': False,
#     'original_language': None,
#     'is_multivolume': False,
#     'series_title': None,
#     'total_volumes': None
# }
# [14/55] Starting books4loading_14.json...
# {
#     'composite_id': 'erstausgaben_594_24_78',
#     'is_active': 1,
#     'title': 'Es geht uns gut',
#     'subtitle': 'Roman',
#     'publisher': 'Hanser',
#     'place_of_publication': 'München',
#     'publication_year': 2005,
#     'edition': None,
#     'pages': 389,
#     'format_original': 'OPbd.m.OU',
#     'format_expanded': 'Originalpappband mit Originalumschlag',
#     'condition': 'Verlagsfrisch',
#     'copies': 1,
#     'illustrations': None,
#     'packaging': None,
#     'topic_id': 27,
#     'is_translation': False,
#     'original_language': None,
#     'is_multivolume': False,
#     'series_title': None,
#     'total_volumes': None
# }
# [15/55] Starting books4loading_15.json...
# {
#     'composite_id': 'erstausgaben_1327_54_78',
#     'is_active': 1,
#     'title': 'Leib und Leben',
#     'subtitle': 'Erzählungen',
#     'publisher': 'Suhrkamp',
#     'place_of_publication': 'Frankfurt',
#     'publication_year': 1982,
#     'edition': None,
#     'pages': 213,
#     'format_original': 'OLn.m.OU',
#     'format_expanded': 'Originalleinen mit Originalumschlag',
#     'condition': 'Neuwertig',
#     'copies': 1,
#     'illustrations': None,
#     'packaging': None,
#     'topic_id': 27,
#     'is_translation': False,
#     'original_language': None,
#     'is_multivolume': False,
#     'series_title': None,
#     'total_volumes': None
# }
# [16/55] Starting books4loading_16.json...
# {
#     'composite_id': 'erstausgaben_1555_63_78',
#     'is_active': 2,
#     'title': 'Odysseus, Verbrecher',
#     'subtitle': 'Schauspiel einer Heimkehr',
#     'publisher': 'S. Fischer',
#     'place_of_publication': 'Frankfurt',
#     'publication_year': 2010,
#     'edition': None,
#     'pages': 115,
#     'format_original': 'Opbd.',
#     'format_expanded': 'Originalpappband',
#     'condition': None,
#     'copies': None,
#     'illustrations': None,
#     'packaging': None,
#     'topic_id': 27,
#     'is_translation': False,
#     'original_language': None,
#     'is_multivolume': False,
#     'series_title': None,
#     'total_volumes': None
# }
# [17/55] Starting books4loading_17.json...
# {
#     'composite_id': 'deutschland_84_4_4',
#     'is_active': 1,
#     'title': 'Geschichte der Deutschen für alle Stände',
#     'subtitle': None,
#     'publisher': None,
#     'place_of_publication': 'Hamburg',
#     'publication_year': 1808,
#     'edition': None,
#     'pages': None,
#     'format_original': 'OPbde.',
#     'format_expanded': 'Originalpappbände',
#     'condition': 'mit schönen Rückenschildern, Kommentar zum Leben und Werk des Autors von unbekannter Hand auf dem
# Vortitelblatt (mit Bleistift), sehr gut erhalten',
#     'copies': 1,
#     'illustrations': 'Mit 3 Kupferstichen',
#     'packaging': None,
#     'topic_id': 10,
#     'is_translation': False,
#     'original_language': None,
#     'is_multivolume': True,
#     'series_title': None,
#     'total_volumes': 3
# }
# [18/55] Starting books4loading_18.json...
# {
#     'composite_id': 'kunstbuecher_27_2_38',
#     'is_active': 1,
#     'title': 'Die Venezianischen Maler der Renaissance',
#     'subtitle': None,
#     'publisher': 'Kurt Wolff Verlag',
#     'place_of_publication': 'München',
#     'publication_year': 1925,
#     'edition': None,
#     'pages': None,
#     'format_original': 'OLn.',
#     'format_expanded': 'Originalleinen',
#     'condition': 'Sehr gut erhalten',
#     'copies': 1,
#     'illustrations': 'Mit 42 Bildtafeln',
#     'packaging': None,
#     'topic_id': 24,
#     'is_translation': False,
#     'original_language': None,
#     'is_multivolume': False,
#     'series_title': None,
#     'total_volumes': None
# }
# [19/55] Starting books4loading_19.json...
# {
#     'composite_id': 'kunstbuecher_892_36_38',
#     'is_active': 1,
#     'title': 'Zwischen Stühlen sitzen',
#     'subtitle': 'Hieronymus Zyxens gesammelte närrische Weisheiten',
#     'publisher': 'Edition Graphischer Zirkel',
#     'place_of_publication': None,
#     'publication_year': None,
#     'edition': 'Auflage von 250 num. Ex. Nr.201',
#     'pages': None,
#     'format_original': None,
#     'format_expanded': None,
#     'condition': 'mit 2 sign. Holzschnitten',
#     'copies': 1,
#     'illustrations': '2 signierte Holzschnitte',
#     'packaging': None,
#     'topic_id': 24,
#     'is_translation': False,
#     'original_language': None,
#     'is_multivolume': False,
#     'series_title': None,
#     'total_volumes': None
# }
# [20/55] Starting books4loading_20.json...
# {
#     'composite_id': 'kunstbuecher_788_32_38',
#     'is_active': 1,
#     'title': 'Giovanni Battista Piranesi',
#     'subtitle': 'Bilder von Orten und Räumen',
#     'publisher': 'Hatje',
#     'place_of_publication': 'Stuttgart',
#     'publication_year': 1994,
#     'edition': None,
#     'pages': 62,
#     'format_original': 'OBrosch.',
#     'format_expanded': 'Originalbroschur',
#     'condition': 'Ungelesen',
#     'copies': 1,
#     'illustrations': 'Mit 31 Abb.',
#     'packaging': None,
#     'topic_id': 24,
#     'is_translation': False,
#     'original_language': None,
#     'is_multivolume': False,
#     'series_title': None,
#     'total_volumes': None
# }
# [21/55] Starting books4loading_21.json...
# {
#     'composite_id': 'kunstbuecher_686_28_38',
#     'is_active': 1,
#     'title': 'Der Holzschnitt',
#     'subtitle': 'Von seinen Anfängen im XV. Jahrhundert bis zur Gegenwart',
#     'publisher': 'Cassirer',
#     'place_of_publication': 'Berlin',
#     'publication_year': 1920,
#     'edition': '4.-8. Tausend',
#     'pages': 52,
#     'format_original': 'OPbd.',
#     'format_expanded': 'Originalpappband',
#     'condition': 'Neuwertig',
#     'copies': 1,
#     'illustrations': 'Mit 16 Abbildungen',
#     'packaging': None,
#     'topic_id': 24,
#     'is_translation': False,
#     'original_language': None,
#     'is_multivolume': False,
#     'series_title': None,
#     'total_volumes': None
# }
# [22/55] Starting books4loading_22.json...
# {
#     'composite_id': 'okkultismus_16_1_8',
#     'is_active': 1,
#     'title': 'Alchimie, Postmoderne und der arme Hölderlin',
#     'subtitle': 'Drei Studien zur philosophischen Hermeneutik',
#     'publisher': 'Passagen Verlag',
#     'place_of_publication': 'Wien',
#     'publication_year': 1995,
#     'edition': None,
#     'pages': 149,
#     'format_original': 'OPbd.',
#     'format_expanded': 'Originalpappband',
#     'condition': 'Sehr gut',
#     'copies': 1,
#     'illustrations': 'Mit zahlr. Abb.',
#     'packaging': None,
#     'topic_id': 1,
#     'is_translation': False,
#     'original_language': None,
#     'is_multivolume': False,
#     'series_title': None,
#     'total_volumes': None
# }
# [23/55] Starting books4loading_23.json...
# {
#     'composite_id': 'de-lit-monographien_184_8_10',
#     'is_active': 1,
#     'title': 'Papst und Humanist',
#     'subtitle': None,
#     'publisher': 'Stiasny',
#     'place_of_publication': 'Graz',
#     'publication_year': 1962,
#     'edition': None,
#     'pages': 127,
#     'format_original': None,
#     'format_expanded': None,
#     'condition': None,
#     'copies': 1,
#     'illustrations': None,
#     'packaging': None,
#     'topic_id': 8,
#     'is_translation': False,
#     'original_language': None,
#     'is_multivolume': False,
#     'series_title': None,
#     'total_volumes': None
# }
# [24/55] Starting books4loading_24.json...
# {
#     'composite_id': 'insel_127_6_27',
#     'is_active': 2,
#     'title': 'Das kleine Buch der Edelsteine',
#     'subtitle': None,
#     'publisher': 'Insel',
#     'place_of_publication': 'Leipzig',
#     'publication_year': 1938,
#     'edition': None,
#     'pages': 39,
#     'format_original': None,
#     'format_expanded': None,
#     'condition': 'Mit einer Widmung auf Vortitel. Neuwertig. Selten!',
#     'copies': 1,
#     'illustrations': 'Farbige Bilder von Hans Lang',
#     'packaging': None,
#     'topic_id': 39,
#     'is_translation': False,
#     'original_language': None,
#     'is_multivolume': False,
#     'series_title': 'Insel-Bücherei Nr. 54',
#     'total_volumes': None
# }
# [25/55] Starting books4loading_25.json...
# {
#     'composite_id': 'insel_304_13_27',
#     'is_active': 2,
#     'title': 'Geschichte Gottfriedens von Berlichingen mit der eisernen Faust',
#     'subtitle': 'Dramatisiert',
#     'publisher': 'Insel',
#     'place_of_publication': 'Leipzig',
#     'publication_year': 1955,
#     'edition': '26.-35. Tsd.',
#     'pages': 127,
#     'format_original': None,
#     'format_expanded': None,
#     'condition': 'Sehr gut erhalten. 2. Ex. 11.-15. Tsd. mit ExLibris von Foregger österr. Justizminister.',
#     'copies': 2,
#     'illustrations': None,
#     'packaging': None,
#     'topic_id': 39,
#     'is_translation': False,
#     'original_language': None,
#     'is_multivolume': False,
#     'series_title': 'Insel-Bücherei',
#     'total_volumes': None
# }
# [26/55] Starting books4loading_26.json...
# {
#     'composite_id': 'insel_205_9_27',
#     'is_active': 1,
#     'title': 'Gedichte',
#     'subtitle': None,
#     'publisher': 'Insel',
#     'place_of_publication': 'Frankfurt',
#     'publication_year': 1961,
#     'edition': None,
#     'pages': None,
#     'format_original': None,
#     'format_expanded': None,
#     'condition': 'Neuwertig',
#     'copies': None,
#     'illustrations': None,
#     'packaging': None,
#     'topic_id': 39,
#     'is_translation': False,
#     'original_language': None,
#     'is_multivolume': False,
#     'series_title': 'Insel-Bücherei',
#     'total_volumes': None
# }
# [27/55] Starting books4loading_27.json...
# {
#     'composite_id': 'zeitschriften_7_1_1',
#     'is_active': 2,
#     'title': 'KURSBUCH',
#     'subtitle': None,
#     'publisher': 'Suhrkamp',
#     'place_of_publication': 'Frankfurt',
#     'publication_year': 1965,
#     'edition': None,
#     'pages': None,
#     'format_original': 'OLn. m. Lesebändchen in Kassette',
#     'format_expanded': 'Originalleinen mit Lesebändchen in Kassette',
#     'condition': None,
#     'copies': None,
#     'illustrations': None,
#     'packaging': 'Kassette',
#     'topic_id': 41,
#     'is_translation': False,
#     'original_language': None,
#     'is_multivolume': True,
#     'series_title': None,
#     'total_volumes': 2
# }
# [28/55] Starting books4loading_28.json...
# {
#     'composite_id': 'signierte_170_7_10',
#     'is_active': 2,
#     'title': 'La Fee aux Miettes',
#     'subtitle': None,
#     'publisher': 'Jose Corti',
#     'place_of_publication': 'Paris',
#     'publication_year': 1947,
#     'edition': 'Eines von 980 num. Ex. mit der Nr. 663',
#     'pages': 185,
#     'format_original': 'OBrosch.',
#     'format_expanded': 'Originalbroschur',
#     'condition': 'Hs. Widmung: <<Ich, Mario Rotter, vermache meinen gesammten Besitz und Vermögen Frau Glavas
# Gordana. Unterschrift. Zeugen: 2 unlesbare Signaturen.>>',
#     'copies': 1,
#     'illustrations': 'Illustrations de Jacques Ferrand',
#     'packaging': None,
#     'topic_id': 35,
#     'is_translation': False,
#     'original_language': None,
#     'is_multivolume': False,
#     'series_title': None,
#     'total_volumes': None
# }
# [29/55] Starting books4loading_29.json...
# {
#     'composite_id': 'buch_69_3_8',
#     'is_active': 1,
#     'title': 'GEBETBUCH DES MICHELINO DA BESOZZO',
#     'subtitle': None,
#     'publisher': 'Prestel',
#     'place_of_publication': 'München',
#     'publication_year': 1981,
#     'edition': None,
#     'pages': 152,
#     'format_original': 'Blindgeprägter Original Samtband in Schuber',
#     'format_expanded': 'Blindgeprägter Original Samtband in Schuber',
#     'condition': 'Verlagsfrisch',
#     'copies': 1,
#     'illustrations': None,
#     'packaging': 'Schuber',
#     'topic_id': 22,
#     'is_translation': False,
#     'original_language': None,
#     'is_multivolume': False,
#     'series_title': None,
#     'total_volumes': None
# }
# [30/55] Starting books4loading_30.json...
# {
#     'composite_id': 'renaissance_2_1_4',
#     'is_active': 2,
#     'title': 'Kunsttheorie in Italien 1450 – 1600',
#     'subtitle': None,
#     'publisher': 'Mäander',
#     'place_of_publication': 'München',
#     'publication_year': 1984,
#     'edition': None,
#     'pages': 137,
#     'format_original': 'OPbd.',
#     'format_expanded': 'Originalpappband',
#     'condition': 'Sehr gut',
#     'copies': 1,
#     'illustrations': 'mit zahlr. Abb.',
#     'packaging': None,
#     'topic_id': 29,
#     'is_translation': True,
#     'original_language': 'Englisch',
#     'is_multivolume': False,
#     'series_title': None,
#     'total_volumes': None
# }
# [31/55] Starting books4loading_31.json...
# {
#     'composite_id': 'mittelalter_15_1_7',
#     'is_active': 0,
#     'title': 'Das Weltreich der Mongolen',
#     'subtitle': 'Dschingis Chans Triumph und Vermächtnis',
#     'publisher': None,
#     'place_of_publication': 'Bergisch-Gladbach',
#     'publication_year': 1988,
#     'edition': None,
#     'pages': 256,
#     'format_original': 'OPbd.',
#     'format_expanded': 'Originalpappband',
#     'condition': 'Sehr gut erhalten',
#     'copies': 1,
#     'illustrations': 'Mit Abb.',
#     'packaging': None,
#     'topic_id': 2,
#     'is_translation': True,
#     'original_language': 'Englisch',
#     'is_multivolume': False,
#     'series_title': None,
#     'total_volumes': None
# }
# [32/55] Starting books4loading_32.json...
# {
#     'composite_id': 'russland_264_11_17',
#     'is_active': 1,
#     'title': 'Geschichte Russlands',
#     'subtitle': None,
#     'publisher': 'WBG',
#     'place_of_publication': 'Darmstadt',
#     'publication_year': 1970,
#     'edition': 'Zweite, überarbeitete und erweiterte Auflage',
#     'pages': None,
#     'format_original': 'O.Kunststoffeinband',
#     'format_expanded': 'Originalkunststoffeinband',
#     'condition': None,
#     'copies': None,
#     'illustrations': None,
#     'packaging': None,
#     'topic_id': 9,
#     'is_translation': False,
#     'original_language': None,
#     'is_multivolume': False,
#     'series_title': None,
#     'total_volumes': None
# }
# [33/55] Starting books4loading_33.json...
# {
#     'composite_id': 'russland_22_1_17',
#     'is_active': 0,
#     'title': 'Übermensch und Antichrist',
#     'subtitle': 'Über das Ende der Weltgeschichte',
#     'publisher': 'Herder',
#     'place_of_publication': 'Freiburg',
#     'publication_year': 1958,
#     'edition': None,
#     'pages': 155,
#     'format_original': 'TB',
#     'format_expanded': 'Taschenbuch',
#     'condition': 'Mit Widmung von Karl Strobl an mich',
#     'copies': 1,
#     'illustrations': None,
#     'packaging': None,
#     'topic_id': 9,
#     'is_translation': True,
#     'original_language': None,
#     'is_multivolume': False,
#     'series_title': None,
#     'total_volumes': None
# }
# [34/55] Starting books4loading_34.json...
# {
#     'composite_id': 'wien_153_7_10',
#     'is_active': 1,
#     'title': 'WIENER ARCHITEKTUR 1860-1930 IN ZEICHNUNGEN',
#     'subtitle': None,
#     'publisher': 'Hatje',
#     'place_of_publication': 'Stuttgart',
#     'publication_year': 1979,
#     'edition': None,
#     'pages': 128,
#     'format_original': 'OLn.m.OU',
#     'format_expanded': 'Originalleinen mit Originalumschlag',
#     'condition': 'Mit einer Widmung beider Autoren',
#     'copies': 1,
#     'illustrations': 'Mit 109 Zeichnungen',
#     'packaging': None,
#     'topic_id': 36,
#     'is_translation': False,
#     'original_language': None,
#     'is_multivolume': False,
#     'series_title': None,
#     'total_volumes': None
# }
# [35/55] Starting books4loading_35.json...
# {
#     'composite_id': 'neuzeit_62_3_4',
#     'is_active': 1,
#     'title': 'Ein verlorenes Paradies',
#     'subtitle': 'Der Jesuitenstaat in Paraguay',
#     'publisher': 'Kösel',
#     'place_of_publication': 'München',
#     'publication_year': 1979,
#     'edition': None,
#     'pages': 329,
#     'format_original': 'OLn.m.OU',
#     'format_expanded': 'Originalleinen mit Originalumschlag',
#     'condition': 'Neuwertig',
#     'copies': 1,
#     'illustrations': 'Mit Abb. und Karten',
#     'packaging': None,
#     'topic_id': 37,
#     'is_translation': True,
#     'original_language': 'Englisch',
#     'is_multivolume': False,
#     'series_title': None,
#     'total_volumes': None
# }
# [36/55] Starting books4loading_36.json...
# {
#     'composite_id': 'de-lit-texte_148_6_20',
#     'is_active': 2,
#     'title': 'Effie Briest',
#     'subtitle': 'Roman',
#     'publisher': 'Manesse',
#     'place_of_publication': 'Zürich',
#     'publication_year': 1963,
#     'edition': None,
#     'pages': 501,
#     'format_original': 'OLn.m.OU und Lesebändchen',
#     'format_expanded': 'Originalleinen mit Originalumschlag und Lesebändchen',
#     'condition': None,
#     'copies': 1,
#     'illustrations': None,
#     'packaging': None,
#     'topic_id': 13,
#     'is_translation': False,
#     'original_language': None,
#     'is_multivolume': False,
#     'series_title': 'Bibliothek der Weltliteratur',
#     'total_volumes': None
# }
# [37/55] Starting books4loading_37.json...
# {
#     'composite_id': 'de-lit-texte_275_12_20',
#     'is_active': 1,
#     'title': 'Erinnerungen an Galizien',
#     'subtitle': None,
#     'publisher': 'Limes',
#     'place_of_publication': 'München',
#     'publication_year': 1975,
#     'edition': None,
#     'pages': 158,
#     'format_original': 'OPbd.m.OU',
#     'format_expanded': 'Originalpappband mit Originalumschlag',
#     'condition': None,
#     'copies': None,
#     'illustrations': None,
#     'packaging': None,
#     'topic_id': 13,
#     'is_translation': False,
#     'original_language': None,
#     'is_multivolume': False,
#     'series_title': None,
#     'total_volumes': None
# }
# [38/55] Starting books4loading_38.json...
# {
#     'composite_id': 'de-lit-texte_46_2_20',
#     'is_active': 1,
#     'title': 'Oberon',
#     'subtitle': 'Ein romantisches Heldengedicht in zwölf Gesängen',
#     'publisher': 'Ch. Kaulfuss & C. Armbruster verlegt zu haben bey Rudolph Sammer',
#     'place_of_publication': 'Wien',
#     'publication_year': 1815,
#     'edition': None,
#     'pages': None,
#     'format_original': 'OBrosch.',
#     'format_expanded': 'Originalbroschur',
#     'condition': 'Sehr gut erhalten',
#     'copies': 1,
#     'illustrations': 'Mit je einem Frontispiz',
#     'packaging': None,
#     'topic_id': 13,
#     'is_translation': False,
#     'original_language': None,
#     'is_multivolume': True,
#     'series_title': None,
#     'total_volumes': 2
# }
# [39/55] Starting books4loading_39.json...
# {
#     'composite_id': 'musik_195_8_11',
#     'is_active': 1,
#     'title': 'Vom Wesen des Musikalischen',
#     'subtitle': 'Grundzüge der Zwölftonmusik',
#     'publisher': 'Lienau Verlag',
#     'place_of_publication': 'Berlin',
#     'publication_year': 1966,
#     'edition': None,
#     'pages': 48,
#     'format_original': 'OBrosch.',
#     'format_expanded': 'Originalbroschur',
#     'condition': None,
#     'copies': 1,
#     'illustrations': 'Mit Beispielen und Anhang',
#     'packaging': None,
#     'topic_id': 34,
#     'is_translation': False,
#     'original_language': None,
#     'is_multivolume': False,
#     'series_title': None,
#     'total_volumes': None
# }
# [40/55] Starting books4loading_40.json...
# {
#     'composite_id': 'biographie_129_6_27',
#     'is_active': 2,
#     'title': 'Albert Camus. Ein Leben',
#     'subtitle': None,
#     'publisher': 'Rowohlt',
#     'place_of_publication': 'Reinbek',
#     'publication_year': 1999,
#     'edition': None,
#     'pages': 923,
#     'format_original': 'OPbd. m OU. Lesebändchen',
#     'format_expanded': 'Originalpappband mit Originalumschlag, Lesebändchen',
#     'condition': 'An den Rändern etwas gebräunt. Sonst tadelloses Ex.',
#     'copies': 1,
#     'illustrations': None,
#     'packaging': None,
#     'topic_id': 42,
#     'is_translation': True,
#     'original_language': 'Französisch',
#     'is_multivolume': False,
#     'series_title': None,
#     'total_volumes': None
# }
# [41/55] Starting books4loading_41.json...
# {
#     'composite_id': 'biographie_427_18_27',
#     'is_active': 1,
#     'title': 'Joseph Roths Flucht und Ende',
#     'subtitle': 'Erinnerungen',
#     'publisher': 'Kiepenheuer & Witsch',
#     'place_of_publication': 'Köln',
#     'publication_year': 2008,
#     'edition': None,
#     'pages': 426,
#     'format_original': 'KiWi Taschenbuch',
#     'format_expanded': 'KiWi Taschenbuch',
#     'condition': None,
#     'copies': 1,
#     'illustrations': None,
#     'packaging': None,
#     'topic_id': 42,
#     'is_translation': False,
#     'original_language': None,
#     'is_multivolume': False,
#     'series_title': None,
#     'total_volumes': None
# }
# [42/55] Starting books4loading_42.json...
# {
#     'composite_id': 'biographie_38_2_27',
#     'is_active': 2,
#     'title': 'Georg Christoph Lichtenberg. 1742 – 1799. Wagnis der Aufklärung',
#     'subtitle': 'Ausstellung Darmstadt 1992',
#     'publisher': 'Hanser',
#     'place_of_publication': 'München',
#     'publication_year': 1992,
#     'edition': None,
#     'pages': 435,
#     'format_original': 'OKart.',
#     'format_expanded': 'Originalkarton',
#     'condition': None,
#     'copies': None,
#     'illustrations': 'Mit zahlr. Abb.',
#     'packaging': None,
#     'topic_id': 42,
#     'is_translation': False,
#     'original_language': None,
#     'is_multivolume': False,
#     'series_title': None,
#     'total_volumes': None
# }
# [43/55] Starting books4loading_43.json...
# {
#     'composite_id': 'islam_13_1_3',
#     'is_active': 1,
#     'title': 'Das Buch des buntbestickten Kleides',
#     'subtitle': 'Ein Anstandsbuch des arabischen Mittelalters',
#     'publisher': 'Schünemann',
#     'place_of_publication': 'Bremen',
#     'publication_year': 1984,
#     'edition': None,
#     'pages': None,
#     'format_original': 'Drei Leinenbände in bunter Kassette',
#     'format_expanded': 'Drei Leinenbände in bunter Kassette',
#     'condition': 'Verlagsfrisch',
#     'copies': 1,
#     'illustrations': None,
#     'packaging': 'Kassette',
#     'topic_id': 38,
#     'is_translation': True,
#     'original_language': 'Arabisch',
#     'is_multivolume': True,
#     'series_title': None,
#     'total_volumes': 3
# }
# [44/55] Starting books4loading_44.json...
# {
#     'composite_id': 'reisen_177_8_13',
#     'is_active': 0,
#     'title': 'HEINRICH DER SEEFAHRER',
#     'subtitle': 'Der Aufbruch ins Zeitalter der Entdeckungen',
#     'publisher': 'Brockhaus',
#     'place_of_publication': 'Wiesbaden',
#     'publication_year': 1979,
#     'edition': None,
#     'pages': 204,
#     'format_original': 'OLn.m.OU',
#     'format_expanded': 'Originalleinen mit Originalumschlag',
#     'condition': None,
#     'copies': None,
#     'illustrations': None,
#     'packaging': None,
#     'topic_id': 6,
#     'is_translation': True,
#     'original_language': None,
#     'is_multivolume': False,
#     'series_title': None,
#     'total_volumes': None
# }
# [45/55] Starting books4loading_45.json...
# {
#     'composite_id': 'reisen_94_4_13',
#     'is_active': 1,
#     'title': 'Afrikafahrt',
#     'subtitle': 'Eine Frau bei den Negern Westafrikas',
#     'publisher': 'Büchergilde Gutenberg',
#     'place_of_publication': 'Wien',
#     'publication_year': 1936,
#     'edition': None,
#     'pages': 240,
#     'format_original': 'OLn.',
#     'format_expanded': 'Originalleinen',
#     'condition': None,
#     'copies': 1,
#     'illustrations': 'mit 101 Abbildungen nach Originalaufnahmen von Hugo Bernatzik und mit einer Karte',
#     'packaging': None,
#     'topic_id': 6,
#     'is_translation': False,
#     'original_language': None,
#     'is_multivolume': False,
#     'series_title': None,
#     'total_volumes': None
# }
# [46/55] Starting books4loading_46.json...
# {
#     'composite_id': 'literatur_40_2_12',
#     'is_active': 1,
#     'title': "'ALS DER KRIEG ZU ENDE WAR'",
#     'subtitle': 'Literarisch-politische Publizistik 1945 – 1950. Eine Ausstellung des Deutschen Literaturarchivs
# Marbach. 1973',
#     'publisher': 'Kösel',
#     'place_of_publication': 'München',
#     'publication_year': 1973,
#     'edition': None,
#     'pages': 591,
#     'format_original': 'OBrosch.',
#     'format_expanded': 'Originalbroschur',
#     'condition': None,
#     'copies': None,
#     'illustrations': 'Mit zahlr. Abb.',
#     'packaging': None,
#     'topic_id': 31,
#     'is_translation': False,
#     'original_language': None,
#     'is_multivolume': False,
#     'series_title': None,
#     'total_volumes': None
# }
# [47/55] Starting books4loading_47.json...
# {
#     'composite_id': 'briefe_322_13_15',
#     'is_active': 1,
#     'title': 'Tagebuch 1930-1935',
#     'subtitle': None,
#     'publisher': 'Insel',
#     'place_of_publication': 'Frankfurt',
#     'publication_year': 1983,
#     'edition': 'Erstausgabe',
#     'pages': None,
#     'format_original': 'OLn.m.OU',
#     'format_expanded': 'Originalleinen mit Originalumschlag',
#     'condition': 'Neuwertig',
#     'copies': 1,
#     'illustrations': None,
#     'packaging': None,
#     'topic_id': 21,
#     'is_translation': False,
#     'original_language': None,
#     'is_multivolume': False,
#     'series_title': None,
#     'total_volumes': None
# }
# [48/55] Starting books4loading_48.json...
# {
#     'composite_id': 'briefe_182_8_15',
#     'is_active': 1,
#     'title': 'Willy Haas: Ein Briefwechsel',
#     'subtitle': None,
#     'publisher': 'Propyläen',
#     'place_of_publication': 'Berlin',
#     'publication_year': 1968,
#     'edition': 'Sonderdruck',
#     'pages': 111,
#     'format_original': 'OBrosch.',
#     'format_expanded': 'Originalbroschur',
#     'condition': None,
#     'copies': 1,
#     'illustrations': None,
#     'packaging': None,
#     'topic_id': 21,
#     'is_translation': False,
#     'original_language': None,
#     'is_multivolume': False,
#     'series_title': None,
#     'total_volumes': None
# }
# [49/55] Starting books4loading_49.json...
# {
#     'composite_id': 'judentum_143_6_9',
#     'is_active': 1,
#     'title': 'Von Berlin nach Jerusalem',
#     'subtitle': 'Jugenderinnerungen',
#     'publisher': 'Suhrkamp',
#     'place_of_publication': 'Frankfurt',
#     'publication_year': 1977,
#     'edition': None,
#     'pages': 220,
#     'format_original': 'OPbd.',
#     'format_expanded': 'Originalpappband',
#     'condition': None,
#     'copies': 1,
#     'illustrations': None,
#     'packaging': None,
#     'topic_id': 20,
#     'is_translation': False,
#     'original_language': None,
#     'is_multivolume': False,
#     'series_title': 'Bibliothek Suhrkamp 555',
#     'total_volumes': None
# }
# [50/55] Starting books4loading_50.json...
# {
#     'composite_id': 'bibliophile_105_5_10',
#     'is_active': 1,
#     'title': 'FRANZÖSISCHE MORALISTEN',
#     'subtitle': 'Ausgewählte Aphorismen von La Rochefoucauld, La Bruyere, Vauvenargues, Chamfort, Rivarol,
# Joubert',
#     'publisher': 'Birkhäuser',
#     'place_of_publication': 'Basel',
#     'publication_year': 1955,
#     'edition': '5. Basler Druck mit der Nummer 740',
#     'pages': 213,
#     'format_original': 'OHPgt.',
#     'format_expanded': 'Originalhalbpergament',
#     'condition': 'mit Kopfgoldschnitt',
#     'copies': 1,
#     'illustrations': None,
#     'packaging': None,
#     'topic_id': 19,
#     'is_translation': True,
#     'original_language': 'Französisch',
#     'is_multivolume': False,
#     'series_title': None,
#     'total_volumes': None
# }
# [51/55] Starting books4loading_51.json...
# {
#     'composite_id': 'illustrierte_333_14_14',
#     'is_active': 2,
#     'title': 'Don Silvio von Rosalva',
#     'subtitle': None,
#     'publisher': 'Schroll',
#     'place_of_publication': 'Wien',
#     'publication_year': 1925,
#     'edition': None,
#     'pages': None,
#     'format_original': 'Illustr. OLn. m. OU.',
#     'format_expanded': 'Originalleinen mit Originalumschlag',
#     'condition': 'Sehr gut erhalten',
#     'copies': 2,
#     'illustrations': 'Mit 24 Originallithographien von Julius Zimpel',
#     'packaging': None,
#     'topic_id': 43,
#     'is_translation': False,
#     'original_language': None,
#     'is_multivolume': False,
#     'series_title': None,
#     'total_volumes': None
# }
# [52/55] Starting books4loading_52.json...
# {
#     'composite_id': 'philosophie_171_7_24',
#     'is_active': 1,
#     'title': 'Über Bedingungen und Möglichkeiten eines neuen Humanismus',
#     'subtitle': 'Drei Vorträge',
#     'publisher': 'Reclam',
#     'place_of_publication': 'Stuttgart',
#     'publication_year': None,
#     'edition': None,
#     'pages': 93,
#     'format_original': None,
#     'format_expanded': None,
#     'condition': None,
#     'copies': None,
#     'illustrations': None,
#     'packaging': None,
#     'topic_id': 46,
#     'is_translation': False,
#     'original_language': None,
#     'is_multivolume': False,
#     'series_title': 'Reclam 8674',
#     'total_volumes': None
# }
# [53/55] Starting books4loading_53.json...
# {
#     'composite_id': 'philosophie_411_17_24',
#     'is_active': 1,
#     'title': 'Der Mensch und sein Tod',
#     'subtitle': 'Certa moriendi conditio',
#     'publisher': None,
#     'place_of_publication': 'Zürich',
#     'publication_year': 1984,
#     'edition': None,
#     'pages': 512,
#     'format_original': 'OLn.m.OU',
#     'format_expanded': 'Originalleinen mit Originalumschlag',
#     'condition': 'Sehr gut erhalten',
#     'copies': 1,
#     'illustrations': 'Mit vielen Abb.',
#     'packaging': None,
#     'topic_id': 46,
#     'is_translation': False,
#     'original_language': None,
#     'is_multivolume': False,
#     'series_title': None,
#     'total_volumes': None
# }
# [54/55] Starting books4loading_54.json...
# {
#     'composite_id': 'philosophie_69_3_24',
#     'is_active': 2,
#     'title': 'Spuren',
#     'subtitle': None,
#     'publisher': 'Suhrkamp',
#     'place_of_publication': 'Berlin',
#     'publication_year': 1960,
#     'edition': 'Neue erweiterte Ausgabe',
#     'pages': 287,
#     'format_original': 'OPb.m.OU',
#     'format_expanded': 'Originalpappband mit Originalumschlag',
#     'condition': None,
#     'copies': 2,
#     'illustrations': None,
#     'packaging': None,
#     'topic_id': 46,
#     'is_translation': False,
#     'original_language': None,
#     'is_multivolume': False,
#     'series_title': 'BS 54',
#     'total_volumes': None
# }
# [55/55] Starting books4loading_55.json...
# {
#     'composite_id': 'oesterreich_66_3_13',
#     'is_active': 1,
#     'title': 'Moderne Malerei in Österreich',
#     'subtitle': None,
#     'publisher': 'Wolfrum',
#     'place_of_publication': 'Wien',
#     'publication_year': 1965,
#     'edition': None,
#     'pages': 209,
#     'format_original': 'OLn. m. Klarsichtfolie. In buntem Originalschuber.',
#     'format_expanded': 'Originalleinen mit Klarsichtfolie. In buntem Originalschuber.',
#     'condition': 'Schönes, neuwertiges Exemplar.',
#     'copies': 1,
#     'illustrations': 'Mit 100 Abb. auf montierten Tafeln.',
#     'packaging': None,
#     'topic_id': 17,
#     'is_translation': False,
#     'original_language': None,
#     'is_multivolume': False,
#     'series_title': None,
#     'total_volumes': None
# }
