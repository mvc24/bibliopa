# %%
import json
import sys
from rich import print as rprint
from pathlib import Path
import re
from datetime import datetime
import csv

nb_dir = Path.cwd()

project_root = nb_dir.parent.parent

sys.path.insert(0, str(project_root))

# %%
path = Path(project_root / "scripts/notebooks/book_admin.json")
with open(path, "r") as f:
   books = json.load(f)

# rprint(books)

ids = [i["book_id"] for i in books]
# ids = [a[0]["book_id"] for k, a in books.items()]
rprint(ids)
# Out:
# [4147, 5841, 5939, 6426, 6826, 8369, 8517, 10616]
