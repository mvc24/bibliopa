# %%
import json
import sys
from rich import print as rprint
from pathlib import Path
import re
from datetime import datetime


nb_dir = Path.cwd()

project_root = nb_dir.parent.parent

sys.path.insert(0, str(project_root))

# %%
notebook_folder = Path(project_root / "scripts/notebooks")

for file in notebook_folder.glob("*.ipynb"):
    rprint(f"notebook found: {file.stem}")
    # datetime.fromtimestamp(file.stat().st_mtime)
    stats = file.stat()
    rprint(stats)
    last_modified = datetime.fromtimestamp(file.stat().st_mtime)
    rprint(f"last modified: {last_modified}")
    break


    # if file.suffix("*.ipynb"):
    #     rprint(f"notbook found: {file.stem}")
# Out:
# notebook found: match_books2people
# os.stat_result(st_mode=33188, st_ino=119314065, st_dev=16777232, st_nlink=1, st_uid=501, st_gid=20, st_size=4122,
# st_atime=1777655524, st_mtime=1777639006, st_ctime=1777639006)
# last modified: 2026-05-01 14:36:46.924145
