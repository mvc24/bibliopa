# %%
import json
import sys
from rich import print as rprint
from pathlib import Path
import re
from itertools import batched

nb_dir = Path.cwd()

project_root = nb_dir.parent.parent

sys.path.insert(0, str(project_root))

# %%
people_batched_folder = Path(project_root / "data_reload/people/people_batched")
people_file = Path(project_root / "data_reload/people/new_people_data.json")

with open(people_file, "r") as f:
   people = json.load(f)

total_people = len(people)

rprint(f"total people: {total_people}")

i = 0

for batch in batched(people, 200):
    people_batch = list(batch)
    i += 1
    batch_id = str(i).zfill(2)
    filename = "people4loading_" + batch_id + ".json"
    file_path = people_batched_folder / filename
    # with open(file_path, "w") as f:
    #     json.dump(people_batch, f, ensure_ascii=False, indent=2)
    # rprint(f"wrote & saved {filename}")
# Out:
# total people: 1130

# %% [markdown]
# testing ground for alembic below

# %%
files = sorted(people_batched_folder.glob("*.json"))
total_files = len(files)

for file_idx, file in enumerate(files, start=1):
    filename = file.name
    rprint(f"[{file_idx}/{total_files}] Starting {filename}...")
    # if filename in finished_batches:
    #     continue

    with open(file, "r") as f:
        people = json.load(f)

    for person_idx, person in enumerate(people, start=1):
        rprint(person_idx, person["unified_id"])
        break
# Out:
# [1/6] Starting people4loading_01.json...
# 1 abegg_martin
# [2/6] Starting people4loading_02.json...
# 1 dorper_sven
# [3/6] Starting people4loading_03.json...
# 1 hoddis_jakob
# [4/6] Starting people4loading_04.json...
# 1 malcolm_norman
# [5/6] Starting people4loading_05.json...
# 1 ramberg-berdyczewski_rahel
# [6/6] Starting people4loading_06.json...
# 1 tesniere_marie-helene
