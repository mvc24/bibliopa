# %%
import json
import sys
from rich import print as rprint
from pathlib import Path
import re

nb_dir = Path.cwd()

project_root = nb_dir.parent.parent

sys.path.insert(0, str(project_root))

from scripts.text_matching import normalise_text,remove_diacritics

# %%
nopes_file = Path(project_root / "scripts/notebooks/nopes_fixed.json")

with open(nopes_file, "r") as f:
   nopes = json.load(f)

# %%
single_count = 0
proper_single = 0
single_check_count = 0
singles_to_check = {}
nope_processed_count = 0

for name, entry in list(nopes.items())[:300]:
    nope_processed_count += 1
    last_norm = entry["last_norm"]
    first_norm = entry["first_norm"]
    single_norm = entry["single_norm"]
    family_name = entry["family_name"]
    name_particles = entry["name_particles"]

    # CREATE UNIFIED ID
    if single_norm:
        single_count += 1
        if single_norm.isalpha():
            unified_id_base = single_norm

            continue

        if " " in single_norm:
            single_strip = single_norm.replace(",", "")
            single_split = single_strip.split(" ")
            if len(single_split) == 2:
                single_first_2 = single_split[0] + "_" + single_split[1]
                unified_id_base = single_first_2
            else:
                single_first_2 = single_split[0] + "_" + single_split[1]
                initials = "_".join(i[0] for i in single_split[2:])
                single_unified = single_first_2 + "_" + initials
                unified_id_base = single_unified


        if last_norm and not family_name:
            proper_single += 1

        if family_name or first_norm:
            single_check_count += 1
            singles_to_check[name] = entry

    elif family_name and not first_norm:
        single_check_count += 1
        singles_to_check[name] = entry

    else:
        if first_norm.isalpha():
            first_unified = first_norm
            # rprint(f"first alpha: {first_unified}")
            continue
        else:
            if " " in first_norm:
                first_strip = first_norm.replace(".", "")
                # rprint(f"stripped: {first_strip}")
                first_split = first_strip.split(" ")
                # rprint(f"split: {first_split}")
                first_full = first_split[0]
                initials = "_".join(n[0] for n in first_split[1:])
                # rprint(f"initials: {initials}")
                first_unified = first_full + "_" + initials
                # rprint(f"first with stuff: {first_unified}")
        unified_id_base = last_norm + "_" + first_unified

    unified_id = remove_diacritics(unified_id_base)
    rprint(f"unified, no diacritics: {unified_id}")
# Out:
# unified, no diacritics: schneidawind_franz_j_a
# unified, no diacritics: graesse_johann_g_t
# unified, no diacritics: portmann_raul_r
# unified, no diacritics: tissot_samuel_a_a_d
# unified, no diacritics: goldhagen_johann_e
# unified, no diacritics: schwarzenberg_karl_p
# unified, no diacritics: holbach_paul-henri_t
# unified, no diacritics: palaiphatos
# unified, no diacritics: stadt_modling
# unified, no diacritics: deutscher_buchgewerbeverein
# unified, no diacritics: staatliche_akademie_f_g_k_u_b_z_l
# unified, no diacritics: gemeinde_wien
# unified, no diacritics: radierwerkstatt_kurt_z_w
# unified, no diacritics: internationale_stiftung_m_s
# unified, no diacritics: zentralburo_der_z_o
# unified, no diacritics: hans_blumenberg-archiv
# unified, no diacritics: verein_der_f_d_w_b_i_k
# unified, no diacritics: kopenhagener_kierkegaard-gesellschaft
# unified, no diacritics: verein_freunde_f_d_s_m
# unified, no diacritics: hamburger_stiftung_z_f_v_w_u_k
# unified, no diacritics: wieland-archiv_biberach/riss
# unified, no diacritics: marktgemeinde_goisern
# unified, no diacritics: die_deutsche_b_l_f_a_m_u_b_u_d_s_b_f_a_m_u_l
# unified, no diacritics: werkstatt_breitenbrunn_e_u_w_f
# unified, no diacritics: arbeitsgemeinschaft_des_m_h
# unified, no diacritics: wasielewski_wilh_j_v
# unified, no diacritics: wasielewski_waldemar_v
# unified, no diacritics: sahagun_fray_b_d
# unified, no diacritics: schrijver_emile_g_l
# unified, no diacritics: voolen_edward_v
# unified, no diacritics: mary_geo_t
# unified, no diacritics: tavernier_jean_b
# unified, no diacritics: philippovich_eugen_v
# unified, no diacritics: piranesi_giovanni_b
# unified, no diacritics: danz_karl
# unified, no diacritics: sweeney_james_r
# unified, no diacritics: norwich_john_j
# unified, no diacritics: pletnjowa_swetlana_a
# unified, no diacritics: malory_sir_t
# unified, no diacritics: losow_irene_v
# unified, no diacritics: balmes_hans_j
# unified, no diacritics: mann_hans_m
# unified, no diacritics: schmidt_i_j
# unified, no diacritics: woodroffe_sir_j
# unified, no diacritics: govinda_l_a
# unified, no diacritics: abs-p_josef_m
# unified, no diacritics: glorez_andreas_v_m
# unified, no diacritics: gartner_wernher_d
# unified, no diacritics: oberdonau_gauamt_f_k_g
# unified, no diacritics: rudolf_kronprinz_e
# unified, no diacritics: delevoy_robert_l
# unified, no diacritics: castaneda_jorge_g
# unified, no diacritics: bismarck_otto_v
# unified, no diacritics: sauter_heinz_v
# unified, no diacritics: pe_li_t
# unified, no diacritics: koch_margit
# unified, no diacritics: mirandola_giovanni_p_d
# unified, no diacritics: bermann_richard_a
# unified, no diacritics: bernatzik_hugo_a
# unified, no diacritics: dolinar_frnce_m
# unified, no diacritics: endl_p_f
# unified, no diacritics: ade_hans_c
# unified, no diacritics: bieber_friedrich_j
# unified, no diacritics: gsell-fels_herbert
# unified, no diacritics: johnston_william_m
# unified, no diacritics: mayer_ludwig_j
# unified, no diacritics: dowski_lee_v
# unified, no diacritics: osterreich_art_c_i_u_k
# unified, no diacritics: ernst_art_c_i_u_k
# unified, no diacritics: garger_art_c_i_u_k
# unified, no diacritics: buchner_friedrich_m
# unified, no diacritics: kampffmeyer_peter
# unified, no diacritics: emerson_charlotte
# unified, no diacritics: miessner_wilhelm
# unified, no diacritics: arnim_gisela_v
# unified, no diacritics: gasset_ortega_y
# unified, no diacritics: kane_elisha_k
# unified, no diacritics: kutzner_elisha_k
# unified, no diacritics: paulus_clementine
