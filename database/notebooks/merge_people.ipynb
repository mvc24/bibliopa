# %%
import json
import sys
from pathlib import Path

nb_dir = Path.cwd()
project_root = nb_dir.parent.parent
sys.path.insert(0, str(project_root))

from rich import print, inspect

from scripts.text_matching import normalise_text
# Out:
# HEREERERE /Users/mariavalencia/Documents/curiosity corner/I love learning/bibliopa

# %%
people_file = Path("../in_progress/people_results.json")
people_grouped_file = Path("../in_progress/people_grouped.json")
inconsistent_file = Path("../in_progress/inconsistent_people.json")
folder_path = Path("../in_progress/pass2_results")
# folder_path = folder_path.resolve()

# %%
org_keywords = ["stiftung", "archiv", "gesellschaft", "forum", "gemeinde", "sammlung", "institut", "museum", "kultur", "kuratorium", "verlag", "ministerium", "akademie", "trust", "verein", "organisation", "vereinigung", "universität", "bibliothek"]

# %% [markdown]
# Check for inconsistencies from API parsing

# %% [markdown]
# parsed_people = []
# check_inconsistencies = {}
# inconsistent = []
#
# with open(people_file, "r") as f:
#     parsed_people = json.load(f)
#
#     for entry in parsed_people:
#         unified_id = entry["unified_id"]
#         family_name = entry.get("family_name")
#         given_names = entry.get("given_names")
#         names = (family_name, given_names)
#
#
#         if unified_id not in check_inconsistencies:
#             check_inconsistencies[unified_id] = {names}
#         else:
#             check_inconsistencies[unified_id].add(names)
#
#         count = len(check_inconsistencies[unified_id])
#         inconsistent_count = 0
#         if count > 1:
#             inconsistent_count += 1
#             inconsistent.append(unified_id)
# inconsistent_people = [uid for uid, name_set in check_inconsistencies.items() if len(name_set) > 1]
# print(f"Total unique people with inconsistencies: {len(inconsistent_people)}")
# print(inconsistent_people)

# %%
parsed_people = []
people_grouped = {}
inconsistent = []
check_inconsistencies = {}

with open(people_file, "r") as f:
    if not people_file.exists():
        raise FileNotFoundError("collected_people file doesn't exist!")
    if not people_grouped_file.exists():
        raise FileNotFoundError("Grouped file doesn't exist!")
    if not inconsistent_file.exists():
        raise FileNotFoundError("inconsistent file")
    parsed_people = json.load(f)

    for entry in parsed_people:

        unified_id = entry["unified_id"]
        family_name = entry.get("family_name")
        family_norm = normalise_text(family_name)
        given_names = entry.get("given_names")
        given_norm = normalise_text(given_names)

        names_norm = (family_norm, given_norm)

        if unified_id not in check_inconsistencies:
            check_inconsistencies[unified_id] = {names_norm}
        else:
            check_inconsistencies[unified_id].add(names_norm)



        count = len(check_inconsistencies[unified_id])
        inconsistent_count = 0
        if count > 1:
            inconsistent_count += 1
            is_inconsistent = True
            inconsistent.append(unified_id)

inconsistent_people = [uid for uid, name_set in check_inconsistencies.items() if len(name_set) > 1]



print(f"Total unique people with inconsistencies: {len(inconsistent_people)}")
print(inconsistent_people)

#         if unified_id not in check_inconsistencies:
#             check_inconsistencies[unified_id] = {names}
#         else:
#             check_inconsistencies[unified_id].add(names)

#         count = len(check_inconsistencies[unified_id])
#         inconsistent_count = 0
#         if count > 1:
#             inconsistent_count += 1
#             inconsistent.append(unified_id)
# inconsistent_people = [uid for uid, name_set in check_inconsistencies.items() if len(name_set) > 1]
# print(f"Total unique people with inconsistencies: {len(inconsistent_people)}")
# print(inconsistent_people)
# Out:
# Total unique people with inconsistencies: 380
# [
#     'heissenbuttel_helmut',
#     'steinlen_theophile',
#     'stendhal',
#     'sterne_laurence',
#     'paracelsus',
#     'patka_marcus_g',
#     'wezel_johann_c',
#     'wheelock_arthur_k',
#     'sachslehner_johannes',
#     'sade_marquis_de',
#     'salis_jean_r_von',
#     'gruber_reinhard_p',
#     'grubrich_simitis_ilse',
#     'kungfutse',
#     'menander',
#     'mendelssohn_bartholdy_felix',
#     'menzel_adolph',
#     'merian_matthaeus',
#     'merkelbach_reinhold',
#     'benz_ernst',
#     'berdjajew_nikolai',
#     'berenson_bernard',
#     'horaz',
#     'hornung_erik',
#     'horvath_odon_von',
#     'hosemann_theodor',
#     'conway_john',
#     'jonke_gert',
#     'eliade_mircea',
#     'eliot_t_s',
#     'adorno_theodor_w',
#     'girard_rene',
#     'glasenapp_helmuth',
#     'gleichen_russwurm_alexander',
#     'laotse',
#     'bin_gorion_micha_j',
#     'binding_rudolf_g',
#     'catull',
#     'cervantes_miguel',
#     'fechner_gustav_t',
#     'federn_karl',
#     'koschatzky_walter',
#     'kosel_hermann_c',
#     'suzuki_daisetz_t',
#     'szafranski',
#     'tacitus_cornelius',
#     'wattenbach_wilhelm',
#     'marx_joseph',
#     'masereel_frans',
#     'masjutin_wassili',
#     'matisse_henri',
#     'holderlin_friedrich',
#     'terenz',
#     'thackeray_william_m',
#     'kokoschka_oskar',
#     'kolleritsch_alfred',
#     'kollontai_alexandra',
#     'plautus_t',
#     'plinius_caecilius_secundus_c',
#     'plutarch',
#     'biedermann_hans',
#     'gnaediger_louise',
#     'goeppert_frank_herma_c',
#     'hesiod',
#     'jessenin_sergej',
#     'johann_von_saaz',
#     'holbein_hans',
#     'hollegha_wolfgang',
#     'homer',
#     'cooper_james_f',
#     'cortazar_julio',
#     'cortes_ferdinand',
#     'meyerhold_wsewolod_e',
#     'michelangelo',
#     'schoenberg_arnold',
#     'scholem_gershom',
#     'kues_niklaus',
#     'ruhm_gerhard',
#     'sacher_masoch_alexander',
#     'sachs_hans',
#     'weiss_walter',
#     'weiss_e_r',
#     'stoll_h_w',
#     'fuhrmann_franz',
#     'braungardt_ganna_maria',
#     'brecht_bertolt',
#     'bredekamp_horst',
#     'neruda_pablo',
#     'nestroy_johann',
#     'bucharin_nikolai',
#     'popper-linkeus_josef',
#     'portmann_adolf',
#     'frankl_viktor_e',
#     'vazquez_montalban_manuel',
#     'vergil',
#     'verosta_stephan',
#     'vetter_hermann',
#     'kertesz_imre',
#     'kerenyi_karl',
#     'liessmann_konrad_p',
#     'linke_karl',
#     'siegmund_schulze_walther',
#     'singer_isaac_b',
#     'rembrandt',
#     'wolfram',
#     'wosnessenski_andrej',
#     'racine_jean',
#     'raddatz_fritz_j',
#     'ramler_carl_w',
#     'ramuz_charles_f',
#     'gurdjieff_g',
#     'guerin_maurice',
#     'gongora_luis',
#     'gorlich_e_j',
#     'mikl_josef',
#     'minder_robert_a',
#     'balzac_honore_de',
#     'barner_winfried',
#     'barrault_jean_l',
#     'barthes_roland',
#     'diderot_denis',
#     'diveky_jozsef',
#     'kalmer_josef',
#     'duerr_hans_p',
#     'dumas_alexandre',
#     'artmann_h_c',
#     'artzibaschew_m',
#     'asch_scholem',
#     'asmussen_jens_p',
#     'mahler_alma',
#     'majakowski_wladimir',
#     'aristoteles',
#     'arnim_achim_von',
#     'hocke_gustav_r',
#     'hoffmann_e_t_a',
#     'mirowa-florin_edel',
#     'mirskij_dimitrij_s',
#     'mitgutsch_waltraud_a',
#     'mitscherlich_alexander',
#     'baedeker',
#     'bakunin_michael',
#     'zizek_slavoj',
#     'schlager_jurgen',
#     'schlegel_august_w',
#     'schlegel_friedrich',
#     'rauchensteiner_manfred',
#     'read',
#     'wolf_hans',
#     'reichel_verena',
#     'solovjev_wladimir',
#     'levi_strauss_claude',
#     'lichatschow_dmitri_s',
#     'lichtenberg_georg_c',
#     'hauff_wilhelm',
#     'villon_francois',
#     'vogeler_heinrich',
#     'turgenev_ivan',
#     'tynyanov_yuri',
#     'ulitskaya_lyudmila',
#     'muschik_johann',
#     'moerike_eduard',
#     'friedenthal_richard',
#     'friedman_thomas_l',
#     'friedrich_der_grosse',
#     'kleukens_christian_h',
#     'brus_gunter',
#     'de_bruyn_gunter',
#     'bowen_elizabeth',
#     'nitsch_hermann',
#     'nodier_charles',
#     'foldenyi_laszlo',
#     'fulop_miller_rene',
#     'galbreath_d_l',
#     'gandhi_m_k',
#     'gantner_joseph',
#     'lawrence_d_h',
#     'voltaire',
#     'voss_johann_h',
#     'de_vries_jan',
#     'dore_gustave',
#     'dorst_tankred',
#     'dostojewski_fjodor_m',
#     'tolstoi_leo',
#     'tophoven_elmar',
#     'klabund',
#     'flaubert_gustave',
#     'flora_paul',
#     'sei_shonagon',
#     'seligmann_adalbert_f',
#     'sempe',
#     'seneca',
#     'burney_c',
#     'borges_jorge_l',
#     'borheck_l_a',
#     'zasche_theo',
#     'zeylmans_van_emmichoven_f_w',
#     'lermontow_m',
#     'leskoschek_axel',
#     'lesskow_nikolaj',
#     'garcia_lorca_federico',
#     'garcia_marquez_gabriel',
#     'gauss_karl_markus',
#     'gawrilow_fjodor',
#     'apuleius',
#     'looser_max',
#     'eckartshausen_karl_v',
#     'eckermann_johann_p',
#     'eckert_willehad_p',
#     'eckhart_meister',
#     'kaufmann_f_m',
#     'unger_heinz_r',
#     'unseld_siegfried',
#     'de_mause_lloyd',
#     'mollat_du_jardin_michel',
#     'de_montaigne_michel',
#     'hadot_pierre',
#     'fries_fritz_r',
#     'wittlin_jozef',
#     'bronner_gerhard',
#     'hartlaub_g_f',
#     'hartmann_otto_j',
#     'spinoza_benedictus',
#     'srbik_heinrich',
#     'rice_david_t',
#     'wingler_hans_m',
#     'zwetajewa_marina',
#     'asop',
#     'gorres_joseph',
#     'gutersloh_albert_p',
#     'guttinger_fritz',
#     'baudelaire_charles',
#     'moritz_karl_p',
#     'moser_christian',
#     'mostar_gerhart_h',
#     'deschner_karlheinz',
#     'dichand',
#     'ehalt_hubert_c',
#     'kampits_peter',
#     'kandinsky_w',
#     'kapuscinski_ryszard',
#     'andersen_hans_c',
#     'andruchowytsch_juri',
#     'lukacs_georg',
#     'lukian',
#     'luther_arthur',
#     'luther_martin',
#     'leitgab_grete_josef',
#     'lenau_nicolaus',
#     'lenin_w_i',
#     'zaepernick_gertraud',
#     'narciss_g_a',
#     'natter_tobias_g',
#     'bonnard_pierre',
#     'pyrker_johann_l',
#     'pueckler_muskau_hermann',
#     'qualtinger_helmut',
#     'quine_willard_v',
#     'quispel_gilles',
#     'rabelais_francois',
#     'bulgakow_michail',
#     'sforim_mendele_m',
#     'shakespeare_william',
#     'shaw_bernard',
#     'kirchner_ernst_l',
#     'tritsch_walter',
#     'trojanow_ilija',
#     'droysen_johann_g',
#     'wacik_franz',
#     'waetzold_wilhelm',
#     'waggerl_karl_h',
#     'attersee_christian_l',
#     'augustinus',
#     'aumuller_uli',
#     'mallarme_stephane',
#     'malraux_andre',
#     'mandiargues_andre_p',
#     'mandeville_bernard',
#     'eichenbaum_boris',
#     'eichendorff_joseph',
#     'czeschka_carl',
#     'huizinga_johan',
#     'hundertwasser',
#     'beethoven_ludwig_v',
#     'behmer_marcus',
#     'ben_chorin_schalom',
#     'mcluhan_herbert_m',
#     'mechthild_von_magdeburg',
#     'scholz_august',
#     'schopenhauer_arthur',
#     'schrijver_emile',
#     'schrott_raoul',
#     'chodowiecki_daniel',
#     'cicero_marcus_t',
#     'sauer_august',
#     'schaarschmidt_richter_irmtraud',
#     'schauer_georg_k',
#     'wilhelm_hellmut',
#     'willemsen_carl_a',
#     'rogler_m_j_b',
#     'stammler_heinrich_a',
#     'stange_hans_o',
#     'stanley_henry_m',
#     'herder_johann_g',
#     'herlitschka_herberth_e',
#     'herlitschka_herberth_marlys',
#     'herodot',
#     'theokrit',
#     'krleza_miroslav',
#     'finley_m_i',
#     'pesendorfer_jo',
#     'petermann_reinhard',
#     'petrarca_francesco',
#     'caesar_gaius_j',
#     'camoes_luiz',
#     'opll_ferdinand',
#     'oppeln_bronikowski_friedrich',
#     'ortega_y_gasset_jose',
#     'block_alexander',
#     'bode_joachim',
#     'bodenstedt_friedrich',
#     'roehl_hermann',
#     'roessler_arthur',
#     'kummel_otto',
#     'lachmann_hedwig',
#     'lackner_nini',
#     'gessner_salomon',
#     'strauss_botho',
#     'stravinsky_igor',
#     'strelka_joseph',
#     'suchy_viktor',
#     'gide_andre',
#     'giedion_welcker_c',
#     'bissing_freiherr_von',
#     'blavatsky_helena_p',
#     'bloch_ernst',
#     'bloch_chaim',
#     'rousseau_jean_j',
#     'rukschcio_burckhardt',
#     'bohmer_gunter',
#     'fitzbauer_erich',
#     'bermann_fischer_gottfried',
#     'bernard_tristan',
#     'tisma_aleksandar',
#     'de_tolnay_charles',
#     'ernesti_jo_a',
#     'euripides',
#     'ewers_hanns_h',
#     'helmle_eugen',
#     'stein_gerhard',
#     'rochowanski_l_w',
#     'roda_roda',
#     'wieland_christoph_m',
#     'wieser_h_s',
#     'chamisso_adelbert_v',
#     'chesterfield_lord',
#     'chi_po_shih',
#     'chiavacci_vinzenz',
#     'chlebnikov_velimir',
#     'samjatin_jewgenij',
#     'saramago_jose',
#     'sarraute_nathalie',
#     'sartre_jean-paul',
#     'goya_francisco',
#     'gracian_baltasar',
#     'grandauer_georg',
#     'schroder_rudolf_a',
#     'beck_hans_georg',
#     'beckett_samuel',
#     'meier_graefe_julius',
#     'meister_guido_g',
#     'dante',
#     'daudet_alphonse',
#     'daumier_honore',
#     'hrdlicka_alfred',
#     'hube_hans_j',
#     'hubmann_franz',
#     'eissler_k_r',
#     'margareta_von_navarra',
#     'martial',
#     'martinz_fritz'
# ]

# %%
# DONE - file created
# parsed_people = []
# for file in folder_path.iterdir():
#     with open(file, "r") as f:
#         people = json.load(f)

#     with open(people_file, "r") as f:
#         parsed_people = json.load(f)
#         parsed_people.extend(people)

#     with open(people_file, "w") as f:
#         json.dump(parsed_people, f, ensure_ascii=False, indent=2)
