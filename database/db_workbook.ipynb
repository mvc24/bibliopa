# %%
import sys
import json
from pathlib import Path

from rich import print as rprint
from rich import inspect

nb_dir = Path.cwd()
project_root = nb_dir.parent
sys.path.insert(0, str(project_root))

from database.connection import get_db_connection

# %%
def get_all_books():
    conn, cur = get_db_connection()
    if conn is None:
        print(f"Connection failed!")
        return

    try:
        SQL = "SELECT * FROM books"
        cur.execute(SQL)
        books = cur.fetchall()
        if books is None:
            print(f"No books were found!")
            return None
        return books

    except Exception as e:
        print(f"Something went wrong!")
        return

    finally:
        conn.close()

# %%
def get_books():
    conn, cur = get_db_connection()
    if conn is None:
        print(f"Connection failed!")
        return

    try:
        SQL = "SELECT * FROM books LIMIT 10"
        cur.execute(SQL)
        books = cur.fetchall()
        if books is None:
            print(f"No books were found!")
            return None
        return books

    except Exception as e:
        print(f"Something went wrong!")
        return

    finally:
        conn.close()

# %%
books = get_books()
# rprint(books)

# %%
def get_all_book_ids():
    conn, cur = get_db_connection()
    if conn is None:
        print(f"Connection failed!")
        return

    try:
        SQL = "SELECT composite_id, book_id FROM books"
        cur.execute(SQL)
        book_ids = cur.fetchall()
        if book_ids is None:
            print(f"No book_ids were were found!")
            return None
        return book_ids

    except Exception as e:
        print(f"Something went wrong!")
        return

    finally:
        conn.close()

# %%
print(get_all_book_ids())
# Out:
# [('symbolkunde_0_1_2', 20705), ('symbolkunde_1_1_2', 20706), ('symbolkunde_2_1_2', 20707), ('symbolkunde_3_1_2', 20708), ('symbolkunde_4_1_2', 20709), ('symbolkunde_5_1_2', 20710), ('symbolkunde_6_1_2', 20711), ('symbolkunde_7_1_2', 20712), ('symbolkunde_8_1_2', 20713), ('symbolkunde_9_1_2', 20714), ('symbolkunde_10_1_2', 20715), ('symbolkunde_11_1_2', 20716), ('symbolkunde_12_1_2', 20717), ('symbolkunde_14_1_2', 20718), ('symbolkunde_15_1_2', 20719), ('symbolkunde_16_1_2', 20720), ('symbolkunde_17_1_2', 20721), ('symbolkunde_18_1_2', 20722), ('symbolkunde_19_1_2', 20723), ('symbolkunde_20_1_2', 20724), ('symbolkunde_21_1_2', 20725), ('symbolkunde_22_1_2', 20726), ('symbolkunde_23_1_2', 20727), ('symbolkunde_24_1_2', 20728), ('symbolkunde_26_2_2', 20729), ('symbolkunde_27_2_2', 20730), ('symbolkunde_28_2_2', 20731), ('symbolkunde_29_2_2', 20732), ('fremdsprachige_44_2_39', 20733), ('fremdsprachige_48_2_39', 20734), ('fremdsprachige_163_7_39', 20735), ('fremdsprachige_210_9_39', 20736), ('fremdsprachige_223_9_39', 20737), ('fremdsprachige_229_10_39', 20738), ('fremdsprachige_256_11_39', 20739), ('fremdsprachige_257_11_39', 20740), ('fremdsprachige_263_11_39', 20741), ('fremdsprachige_332_14_39', 20742), ('fremdsprachige_393_16_39', 20743), ('fremdsprachige_420_17_39', 20744), ('fremdsprachige_472_19_39', 20745), ('bibliophile_92_4_9', 20746), ('bibliophile_93_4_9', 20747), ('f